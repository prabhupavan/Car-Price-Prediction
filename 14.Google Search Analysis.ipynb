# %%
# Google doesn't give much access to the data about daily search queries, but another application of google known as Google Trends can be used for the task of Google Search analysis.
# Google Trends provides an API thst can be used to analyze that daily searches on Google.

import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq
trends = TrendReq()

# %%
# 

trends.build_payload(kw_list=['Pubg'])
data = trends.interest_by_region()
data = data.sort_values(by='Pubg', ascending=False)
data = data.head(10)
data
# Out:
#                  Pubg
# geoName
# Myanmar (Burma)   100
# Mongolia           72
# Nepal              58
# Afghanistan        50
# Pakistan           45
# Iraq               43
# Kosovo             35
# India              33
# Azerbaijan         32
# Uzbekistan         29

# %% [markdown]
# ## Visualization

# %%
data.reset_index().plot(x='geoName', y='Pubg', figsize=(20,15), kind='bar')
# plt.style.use('fivethirtyeight')
plt.show()

# %%
#  How ML-AI has been trending over time

data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Pubg'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize = (20,15))
data['Pubg'].plot()
# plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Machine Learning', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %% [markdown]
# ## So we can see that searches based on “ML AI” on Google started to increase in 2017 and the highest searches were done in 2020 till today.
